# %% [markdown]
# <h1>
# Exercício 4
# </h1>
# <h2>
# Vamos tentar criar um modelo temporal para prever o valor aprovado de crédito para um dia futuro.
# </h2>

# %% [markdown]
# # Bibliotecas

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import math

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.impute import KNNImputer

from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout
from keras.layers import LSTM, GRU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import acf

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Funções Auxiliares

# %%
def create_dataset(dataset, look_back=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), 0]
		dataX.append(a)
		dataY.append(dataset[i+look_back, 0])
	return np.array(dataX), np.array(dataY)

def plot_history(history):
    mse = history.history['loss']
    val_mse = history.history['val_loss']
    x = range(1, len(mse) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, mse, 'b', label='Training MSE')
    plt.plot(x, val_mse, 'r', label='Validation MSE')
    plt.title('Training and validation LOSS - MSE')
    plt.xlabel('epoca')
    plt.ylabel('mse')
    plt.legend()
    
# Accuracy metrics
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-actual)[1]                      # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'acf1':acf1, 
            'corr':corr, 'minmax':minmax})

def percentual_outlier(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    minimum = Q1 - (1.5 * IQR)
    maximum = Q3 + (1.5 * IQR)
    num_outliers =  np.sum((data < minimum) | (data > maximum))
    num_total = data.count()
    return (num_outliers/num_total)*100

# %% [markdown]
# <h1>
# Carregando os dados iniciais
# </h1>
# <h2>
# Para este exercício vamos carregar a base original pois iremos trabalhar apenas com as variáveis: valor aprovado e datas de aprovação.
# </h2>

# %%
df = pd.read_csv("solicitacoescredito.csv")
df.head()
# Out:
#    numero_solicitacao             razaoSocial        nomeFantasia  \
# 0                   1  James Richardson-Patel  Alexandra Williams
# 1                   2      Dr. Geoffrey Walsh   Mr. Darren Arnold
# 2                   3           Joanna Hudson      Dr. David Rees
# 3                   4    Gordon Jones-Hopkins    Sara Reid-Robson
# 4                   5               Nigel Lee  Dr. Stanley Duncan
#
#          cnpjSemTraco  maiorAtraso  margemBrutaAcumulada  percentualProtestos  \
# 0  KEBE17609492220843            0              0.252448                  0.0
# 1  JRBK88908250677300            0              0.000000                  NaN
# 2  GCVQ28531614261293            4              0.624777                  0.0
# 3  KJND32266018316396           20              0.000000                  NaN
# 4  CGQN15826802440348           20              0.454088                  0.0
#
#         primeiraCompra  prazoMedioRecebimentoVendas  titulosEmAberto  ...  \
# 0  2015-12-10T00:00:00                            0             0.00  ...
# 1  2019-06-12T17:28:31                            0             0.00  ...
# 2  2019-11-27T00:00:00                            0             0.00  ...
# 3  2017-02-13T17:20:27                            0             0.00  ...
# 4  2010-07-13T00:00:00                           20          1486.95  ...
#
#    periodoDemonstrativoEmMeses      custos anoFundacao  intervaloFundacao  \
# 0                         12.0         0.0      2003.0   Acima de 17 anos
# 1                          NaN         NaN         NaN                NaN
# 2                          7.0         0.0      2014.0     De 6 a 10 anos
# 3                         12.0         0.0      2013.0     De 6 a 10 anos
# 4                          9.0  40680051.0      2002.0   Acima de 17 anos
#
#    capitalSocial  restricoes  empresa_MeEppMei scorePontualidade  \
# 0        90000.0       False              True               1.0
# 1            NaN         NaN               NaN               0.0
# 2        20000.0       False              True               1.0
# 3        30000.0       False              True               0.0
# 4        75000.0       False             False               1.0
#
#   limiteEmpresaAnaliseCredito  dataAprovadoNivelAnalista
# 0                     43200.0        2020-02-03T20:57:33
# 1                         NaN                        NaN
# 2                      4320.0        2020-02-04T16:40:49
# 3                      5920.0        2020-02-04T16:37:52
# 4                     89000.0        2020-02-04T15:06:28
#
# [5 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8973 entries, 0 to 8972
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   numero_solicitacao           8973 non-null   int64
#  1   razaoSocial                  8973 non-null   object
#  2   nomeFantasia                 8973 non-null   object
#  3   cnpjSemTraco                 8973 non-null   object
#  4   maiorAtraso                  8973 non-null   int64
#  5   margemBrutaAcumulada         8973 non-null   float64
#  6   percentualProtestos          7475 non-null   float64
#  7   primeiraCompra               8867 non-null   object
#  8   prazoMedioRecebimentoVendas  8973 non-null   int64
#  9   titulosEmAberto              8973 non-null   float64
#  10  valorSolicitado              8973 non-null   float64
#  11  status                       8973 non-null   object
#  12  definicaoRisco               8973 non-null   object
#  13  diferencaPercentualRisco     8973 non-null   float64
#  14  percentualRisco              8973 non-null   float64
#  15  dashboardCorrelacao          8973 non-null   float64
#  16  valorAprovado                7569 non-null   float64
#  17  dataAprovadoEmComite         558 non-null    object
#  18  periodoBalanco               4733 non-null   object
#  19  ativoCirculante              4733 non-null   float64
#  20  passivoCirculante            4733 non-null   float64
#  21  totalAtivo                   4733 non-null   float64
#  22  totalPatrimonioLiquido       4733 non-null   float64
#  23  endividamento                4733 non-null   float64
#  24  duplicatasAReceber           4733 non-null   float64
#  25  estoque                      4733 non-null   float64
#  26  faturamentoBruto             8223 non-null   float64
#  27  margemBruta                  8223 non-null   float64
#  28  periodoDemonstrativoEmMeses  8223 non-null   float64
#  29  custos                       8223 non-null   float64
#  30  anoFundacao                  8228 non-null   float64
#  31  intervaloFundacao            8228 non-null   object
#  32  capitalSocial                8228 non-null   float64
#  33  restricoes                   8228 non-null   object
#  34  empresa_MeEppMei             8228 non-null   object
#  35  scorePontualidade            8973 non-null   float64
#  36  limiteEmpresaAnaliseCredito  8228 non-null   float64
#  37  dataAprovadoNivelAnalista    7011 non-null   object
# dtypes: float64(23), int64(3), object(12)
# memory usage: 2.6+ MB

# %% [markdown]
# <h2>
# Abaixo vamos reduzir a base para ficar apenas com a data em que cada crédito foi aprovado e o seu valor.
# </h2>

# %%
df_temporal = df[['dataAprovadoNivelAnalista', 'dataAprovadoEmComite', 'valorAprovado']]
df_temporal['dataAprovadoEmComite'].fillna(df_temporal['dataAprovadoNivelAnalista'], inplace=True)
df_temporal.drop('dataAprovadoNivelAnalista', axis=1, inplace=True)
df_temporal.rename({'dataAprovadoEmComite': 'data', 'valorAprovado': 'valor'}, axis=1, inplace=True)
df_temporal.dropna(inplace=True)
df_temporal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7569 entries, 0 to 8961
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    7569 non-null   object
#  1   valor   7569 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 177.4+ KB

# %% [markdown]
# <h2>
# Ajustamos a data para retirar os horários e ficar apenas com os dias.
# </h2>

# %%
df_temporal.data = [x[:-9] for x in df_temporal.data]
df_temporal.valor = df_temporal.valor.astype('int64')
df_temporal
# Out:
#             data    valor
# 0     2020-02-03    50000
# 2     2020-02-04    20000
# 3     2020-02-04    15000
# 4     2020-02-04    50000
# 5     2020-02-04    20000
# ...          ...      ...
# 8956  2021-02-25    45000
# 8957  2021-02-25    15000
# 8958  2021-02-25  1500000
# 8960  2021-02-25    20000
# 8961  2021-02-25  1800000
#
# [7569 rows x 2 columns]

# %% [markdown]
# <h2>
# Verificando a presença de Extremos (Outliers) no campor valor
# </h2>

# %%
perc = str(round(percentual_outlier(df_temporal.valor), 2))
print(f'Extremos em valor : {perc}%')
# Out:
# Extremos em valor : 15.52%

# %% [markdown]
# <h2>
# Possuímos um valor elevado de extremos que irão dificultar o LSTM.<BR>
# Vamos retirá-los,
# </h2>

# %%
data = df_temporal.valor

Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR = Q3 - Q1
minimum = Q1 - (1.5 * IQR)
maximum = Q3 + (1.5 * IQR)

outliers = ((data < minimum) | (data > maximum))
df_temporal.valor.loc[outliers] = np.nan

df_temporal.dropna(inplace=True)

# %% [markdown]
# <h2>
# Precisamos agrupar os dias iguais, somando os valores para termos um total por dia.
# </h2>

# %%
df_temporal_agrupado = df_temporal.groupby('data', as_index=False).sum()
df_temporal_agrupado.sort_values('data', inplace=True)
df_temporal_agrupado
# Out:
#            data      valor
# 0    2020-02-03    50000.0
# 1    2020-02-04   105000.0
# 2    2020-02-05   702000.0
# 3    2020-02-06  1295000.0
# 4    2020-02-07  2055000.0
# ..          ...        ...
# 255  2021-02-19   951900.0
# 256  2021-02-22   832000.0
# 257  2021-02-23   816500.0
# 258  2021-02-24  1605000.0
# 259  2021-02-25  1580000.0
#
# [260 rows x 2 columns]

# %% [markdown]
# <h2>
# Ao agurupar os dias percebemos que não estão contínuos. Existem diversas falhas na seguência e nem todas podem ser explicadas por final de semana ou feriado.<BR>
# Decidimos então criar uma base com todos os dias e unir as duas.
# </h2>

# %%
df_base_dias = pd.date_range(start='2020-02-03', end='2021-02-25')
df_base_dias = df_base_dias.format(formatter=lambda x: x.strftime('%Y-%m-%d'))
df_base_dias = pd.DataFrame(df_base_dias, columns=['data'])
df_base_dias
# Out:
#            data
# 0    2020-02-03
# 1    2020-02-04
# 2    2020-02-05
# 3    2020-02-06
# 4    2020-02-07
# ..          ...
# 384  2021-02-21
# 385  2021-02-22
# 386  2021-02-23
# 387  2021-02-24
# 388  2021-02-25
#
# [389 rows x 1 columns]

# %%
df_temporal = pd.merge(df_base_dias, df_temporal_agrupado, how='left')
df_temporal.data = df_temporal.index + 1
df_temporal.rename({'data': 'dia'}, axis=1, inplace=True)
df_temporal
# Out:
#      dia      valor
# 0      1    50000.0
# 1      2   105000.0
# 2      3   702000.0
# 3      4  1295000.0
# 4      5  2055000.0
# ..   ...        ...
# 384  385        NaN
# 385  386   832000.0
# 386  387   816500.0
# 387  388  1605000.0
# 388  389  1580000.0
#
# [389 rows x 2 columns]

# %% [markdown]
# <h2>
# Agora temos os dados faltantes que iremos preencher com um KNNInputer.<BR>
# Este método vais usar a média entre os K vizinhos.
# </h2>

# %%
df_temporal.isnull().sum()
# Out:
# dia        0
# valor    129
# dtype: int64

# %%
fig = plt.figure(figsize=(20,10))
sns.scatterplot(x=df_temporal.dia, y=df_temporal.valor)
plt.show()

# %%
imputer = KNNImputer(n_neighbors=4)
knn = imputer.fit_transform(df_temporal)
knn = knn.astype('int64')
knn
# Out:
# array([[      1,   50000],
#        [      2,  105000],
#        [      3,  702000],
#        [      4, 1295000],
#        [      5, 2055000],
#        [      6, 1049625],
#        [      7, 1468625],
#        [      8, 1955625],
#        [      9,  146500],
#        [     10, 2378000],
#        [     11, 3243000],
#        [     12, 2091375],
#        [     13, 2235250],
#        [     14, 2092350],
#        [     15, 2598000],
#        [     16,  722000],
#        [     17, 1806400],
#        [     18, 1737800],
#        [     19, 1480000],
#        [     20, 1662925],
#        [     21, 1662925],
#        [     22, 1768775],
#        [     23, 1768775],
#        [     24, 1627500],
#        [     25, 2116400],
#        [     26, 1851200],
#        [     27, 1757775],
#        [     28, 1526900],
#        [     29, 1436000],
#        [     30,  704000],
#        [     31, 1333000],
#        [     32, 1065000],
#        [     33, 1056950],
#        [     34, 1199987],
#        [     35, 1581062],
#        [     36, 1345000],
#        [     37, 1678500],
#        [     38, 2243800],
#        [     39, 1609090],
#        [     40,  985000],
#        [     41, 1565772],
#        [     42, 1996325],
#        [     43, 2249000],
#        [     44, 1420000],
#        [     45, 3331300],
#        [     46, 1754220],
#        [     47, 1548500],
#        [     48, 1019430],
#        [     49, 1019430],
#        [     50,  450000],
#        [     51,  325000],
#        [     52,  390000],
#        [     53,  298750],
#        [     54,  298750],
#        [     55,  212750],
#        [     56,  179000],
#        [     57,   30000],
#        [     58,  169000],
#        [     59,  106000],
#        [     60,  190000],
#        [     61,  350000],
#        [     62,  197750],
#        [     63,  196250],
#        [     64,  197500],
#        [     65,  145000],
#        [     66,  100000],
#        [     67,  195000],
#        [     68,  152500],
#        [     69,  240000],
#        [     70,  292500],
#        [     71,  170000],
#        [     72,  495000],
#        [     73,  310000],
#        [     74,  161000],
#        [     75,  200000],
#        [     76,  187750],
#        [     77,  181500],
#        [     78,   80000],
#        [     79,  260000],
#        [     80,  285000],
#        [     81,   65000],
#        [     82,  610000],
#        [     83,  388750],
#        [     84,  541875],
#        [     85,  385000],
#        [     86,  495000],
#        [     87,  677500],
#        [     88,  369500],
#        [     89,  481750],
#        [     90,  692500],
#        [     91,  875500],
#        [     92,  910000],
#        [     93, 1228000],
#        [     94, 1227000],
#        [     95,  479000],
#        [     96,  706000],
#        [     97,   25000],
#        [     98,  912250],
#        [     99, 1293000],
#        [    100, 1625000],
#        [    101,  996000],
#        [    102,  779900],
#        [    103,  470000],
#        [    104,  794175],
#        [    105, 1017150],
#        [    106,  682800],
#        [    107, 1244000],
#        [    108, 1671800],
#        [    109, 1241500],
#        [    110,  975000],
#        [    111, 1150075],
#        [    112,  754000],
#        [    113,  712000],
#        [    114, 1094000],
#        [    115,  235000],
#        [    116, 2164500],
#        [    117, 1258500],
#        [    118, 1157000],
#        [    119, 1275250],
#        [    120,  970000],
#        [    121,  708000],
#        [    122,  395000],
#        [    123,  495000],
#        [    124,  862000],
#        [    125,  681000],
#        [    126,  777250],
#        [    127,  896000],
#        [    128,  471000],
#        [    129,  880000],
#        [    130,  754750],
#        [    131,  772000],
#        [    132,  897700],
#        [    133,  816450],
#        [    134, 1032800],
#        [    135,  906000],
#        [    136,  555000],
#        [    137,  850000],
#        [    138, 1485000],
#        [    139,  961250],
#        [    140, 1011500],
#        [    141,  955000],
#        [    142,  660000],
#        [    143,  946000],
#        [    144, 1399000],
#        [    145, 1405000],
#        [    146, 1180975],
#        [    147, 1180975],
#        [    148,  600000],
#        [    149, 1319900],
#        [    150,  678000],
#        [    151,  730000],
#        [    152,  601000],
#        [    153,  635250],
#        [    154,  635250],
#        [    155,  940000],
#        [    156,  270000],
#        [    157, 1992000],
#        [    158, 1491990],
#        [    159, 1336100],
#        [    160, 1471522],
#        [    161, 1125302],
#        [    162, 1066000],
#        [    163, 1315120],
#        [    164,  783990],
#        [    165, 1751000],
#        [    166,  710000],
#        [    167, 1085997],
#        [    168, 1368750],
#        [    169, 1099000],
#        [    170, 1915000],
#        [    171, 1185000],
#        [    172, 1218000],
#        [    173, 1173000],
#        [    174, 1013250],
#        [    175, 1133500],
#        [    176,  477000],
#        [    177, 1667000],
#        [    178, 1217000],
#        [    179, 1169000],
#        [    180, 1627100],
#        [    181, 1105275],
#        [    182, 1091775],
#        [    183,  877000],
#        [    184,  748000],
#        [    185, 1115000],
#        [    186,  831000],
#        [    187, 2432100],
#        [    188, 1553025],
#        [    189, 1553025],
#        [    190,  552000],
#        [    191, 2397000],
#        [    192, 1556000],
#        [    193, 1042001],
#        [    194,  717000],
#        [    195, 1098375],
#        [    196, 1098375],
#        [    197, 1009500],
#        [    198, 1625000],
#        [    199, 1133000],
#        [    200, 1749000],
#        [    201,  750150],
#        [    202, 1087512],
#        [    203, 1090262],
#        [    204,  717900],
#        [    205, 1208000],
#        [    206, 1685000],
#        [    207, 1065600],
#        [    208, 1108000],
#        [    209, 1505275],
#        [    210, 1400875],
#        [    211, 2162500],
#        [    212,  510000],
#        [    213, 1823000],
#        [    214,  640000],
#        [    215, 1750000],
#        [    216, 1319000],
#        [    217, 1111975],
#        [    218, 1246975],
#        [    219, 1063000],
#        [    220,  994900],
#        [    221, 1180000],
#        [    222,  994000],
#        [    223, 1173350],
#        [    224, 1322500],
#        [    225, 1524500],
#        [    226, 1591500],
#        [    227, 1835000],
#        [    228, 1500000],
#        [    229, 1104000],
#        [    230, 1606875],
#        [    231, 1335125],
#        [    232, 1988500],
#        [    233,  950000],
#        [    234, 1298000],
#        [    235, 1265000],
#        [    236,  972010],
#        [    237,  977752],
#        [    238, 1077502],
#        [    239,  376000],
#        [    240, 1481000],
#        [    241, 1481000],
#        [    242,  425000],
#        [    243,  364900],
#        [    244,  689975],
#        [    245,  770975],
#        [    246,  489000],
#        [    247,  951000],
#        [    248, 1279000],
#        [    249, 1318700],
#        [    250,  323000],
#        [    251,  967675],
#        [    252, 1180675],
#        [    253, 1168500],
#        [    254,  950000],
#        [    255, 2131000],
#        [    256, 1270000],
#        [    257, 1029000],
#        [    258, 1132500],
#        [    259, 1108250],
#        [    260, 1120000],
#        [    261, 1111000],
#        [    262, 1173000],
#        [    263,  487000],
#        [    264, 1089000],
#        [    265,  586502],
#        [    266,      10],
#        [    267,  770000],
#        [    268,  764000],
#        [    269, 1425000],
#        [    270, 1044000],
#        [    271,  858000],
#        [    272, 1221475],
#        [    273, 1186975],
#        [    274, 1045975],
#        [    275, 1558900],
#        [    276, 1287000],
#        [    277,  480000],
#        [    278,  867000],
#        [    279,  954500],
#        [    280,  935597],
#        [    281, 1184000],
#        [    282,  889000],
#        [    283,  802390],
#        [    284,  885000],
#        [    285, 1647600],
#        [    286, 1073900],
#        [    287, 1337400],
#        [    288, 1053000],
#        [    289,  710000],
#        [    290, 1939000],
#        [    291,  682000],
#        [    292,  829900],
#        [    293, 1170349],
#        [    294, 1330849],
#        [    295, 1230499],
#        [    296, 2463000],
#        [    297,  800000],
#        [    298, 1445000],
#        [    299,  792800],
#        [    300, 1137125],
#        [    301, 1137125],
#        [    302,  975000],
#        [    303, 1335700],
#        [    304, 4022000],
#        [    305, 1808000],
#        [    306, 1858000],
#        [    307, 2183250],
#        [    308, 1558125],
#        [    309, 1045000],
#        [    310, 1653000],
#        [    311, 1676500],
#        [    312, 1362600],
#        [    313,  685000],
#        [    314, 1106400],
#        [    315, 1148723],
#        [    316, 1128000],
#        [    317, 1250000],
#        [    318, 1531895],
#        [    319, 1290000],
#        [    320,  359500],
#        [    321,  673875],
#        [    322,  673875],
#        [    323,  571000],
#        [    324,  475000],
#        [    325, 1425500],
#        [    326, 1034625],
#        [    327, 1478625],
#        [    328, 1503625],
#        [    329, 1230500],
#        [    330, 1667000],
#        [    331, 2347000],
#        [    332,  575000],
#        [    333,  333000],
#        [    334,  873750],
#        [    335,  504000],
#        [    336,  485250],
#        [    337,  240000],
#        [    338,  868000],
#        [    339,  500000],
#        [    340, 1671000],
#        [    341, 1076500],
#        [    342, 1197875],
#        [    343, 1197875],
#        [    344, 1359000],
#        [    345,  685000],
#        [    346, 1412000],
#        [    347, 1743000],
#        [    348, 1059000],
#        [    349, 1299250],
#        [    350, 1160000],
#        [    351,  983000],
#        [    352,  855000],
#        [    353, 2095000],
#        [    354,  977000],
#        [    355,  875000],
#        [    356, 1260250],
#        [    357, 1206500],
#        [    358, 1177350],
#        [    359, 1094000],
#        [    360, 1880000],
#        [    361,  860400],
#        [    362, 2313000],
#        [    363, 1518850],
#        [    364, 1573800],
#        [    365, 1022000],
#        [    366,  774700],
#        [    367, 2185500],
#        [    368,  710000],
#        [    369,  434900],
#        [    370,  851500],
#        [    371,  825475],
#        [    372,  944000],
#        [    373, 1071500],
#        [    374, 1762600],
#        [    375,  817000],
#        [    376, 1045800],
#        [    377, 1174225],
#        [    378, 1025350],
#        [    379,  935300],
#        [    380,  935300],
#        [    381,  476000],
#        [    382, 1267500],
#        [    383,  951900],
#        [    384,  966975],
#        [    385,  966975],
#        [    386,  832000],
#        [    387,  816500],
#        [    388, 1605000],
#        [    389, 1580000]], dtype=int64)

# %%
df_dias = pd.DataFrame(knn[:,1], columns=['valor'])
df_dias
# Out:
#        valor
# 0      50000
# 1     105000
# 2     702000
# 3    1295000
# 4    2055000
# ..       ...
# 384   966975
# 385   832000
# 386   816500
# 387  1605000
# 388  1580000
#
# [389 rows x 1 columns]

# %%
fig = plt.figure(figsize=(20,8))
sns.scatterplot(x=df_dias.index, y=df_dias.valor)
plt.title('Valor aprovado por dia', size=24)
plt.show()

# %%
sns.histplot(df_dias)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df_dias.describe()
# Out:
#               valor
# count  3.890000e+02
# mean   1.084995e+06
# std    5.681374e+05
# min    1.000000e+01
# 25%    7.100000e+05
# 50%    1.065000e+06
# 75%    1.400875e+06
# max    4.022000e+06

# %% [markdown]
# # Modelo ARIMA

# %% [markdown]
# # Previsão por Dia

# %%
df_arima = df_dias.copy()

result = adfuller(df_arima)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -5.903293
# p-value: 0.000000

# %%
# Original Series
fig, axes = plt.subplots(3, 2, sharex=True, figsize=(20,16))
axes[0, 0].plot(df_arima.valor)
axes[0, 0].set_title('Original Series')
plot_acf(df_arima.valor, ax=axes[0, 1], lags=388)

# 1st Differencing
axes[1, 0].plot(df_arima.valor.diff())
axes[1, 0].set_title('1st Order Differencing')
plot_acf(df_arima.valor.diff().dropna(), ax=axes[1, 1], lags=387)

# 2nd Differencing
axes[2, 0].plot(df_arima.valor.diff().diff())
axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df_arima.valor.diff().diff().dropna(), ax=axes[2, 1], lags=386)

plt.show()

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df_arima.valor.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(df_arima.valor.diff().dropna(), ax=axes[1], lags=190)

plt.show()

# %%
fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df_arima.valor.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(df_arima.valor.diff().dropna(), ax=axes[1], lags=387)

plt.show()

# %%
model = ARIMA(df_arima.valor, order=(1,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.valor   No. Observations:                  388
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -5629.787
# Method:                       css-mle   S.D. of innovations         484013.450
# Date:                Sat, 11 Sep 2021   AIC                          11267.574
# Time:                        14:36:12   BIC                          11283.418
# Sample:                             1   HQIC                         11273.856
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          3943.2989   7011.158      0.562      0.574   -9798.319    1.77e+04
# ar.L1.D.valor     0.0102      0.090      0.114      0.910      -0.166       0.187
# ma.L1.D.valor    -0.7281      0.076     -9.606      0.000      -0.877      -0.580
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           97.9033           +0.0000j           97.9033            0.0000
# MA.1            1.3734           +0.0000j            1.3734            0.0000
# -----------------------------------------------------------------------------

# %%
# Plot residual errors
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0], legend=False)
residuals.plot(kind='kde', title='Density', ax=ax[1], legend=False)
plt.show()

# %%
# Actual vs Fitted
model_fit.plot_predict(dynamic=False)
plt.title('Previsão x Original')
plt.show()

# %%
# Create Training and Test
train_arima = df_arima.valor[:374]
test_arima = df_arima.valor[374:]

# %%
model = ARIMA(df_arima.valor, order=(1,1,1))
model_fit = model.fit(disp=1)

# Forecast
fc, se, conf = model_fit.forecast(15, alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_arima.index)
lower_series = pd.Series(conf[:, 0], index=test_arima.index)
upper_series = pd.Series(conf[:, 1], index=test_arima.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train_arima, label='training')
plt.plot(test_arima, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='r', alpha=.15)
plt.title('Previsão x Original')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
mean_absolute_percentage_error(fc_series, test_arima)
# Out:
# 0.25320817805854196

# %% [markdown]
# # Previsão por Dias

# %%
X = np.array(df_temporal.valor)
X = X.astype('float32').reshape(-1,1)

# %%
X.shape
# Out:
# (264, 1)

# %%
scaler = MinMaxScaler()
#scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
train_size = int(len(X) * 0.7)
test_size = len(X) - train_size

train = X[0:train_size,:]
test =  X[train_size:len(X),:]

# %%
plt.plot(train)

# %%
plt.plot(test)

# %%
best = 0
best_mse = np.Infinity
for n in range(51, 61, 1):
    look_back = n
    X_train, y_train = create_dataset(train, look_back)
    X_test, y_test = create_dataset(test, look_back)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    model = Sequential()
    model.add(LSTM(128, input_shape=(look_back, 1), dropout=0.2))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=1, verbose=0)
    mse = min(history.history['val_loss'])
    if best_mse > mse:
        best_mse = mse
        best = n
    print(f"look back {n} - {mse} | best {best} - {best_mse}")
# Out:
# look back 51 - 0.021117042750120163 | best 51 - 0.021117042750120163
# look back 52 - 0.019790098071098328 | best 52 - 0.019790098071098328
# look back 53 - 0.019168533384799957 | best 53 - 0.019168533384799957
# look back 54 - 0.016666855663061142 | best 54 - 0.016666855663061142
# look back 55 - 0.017085256054997444 | best 54 - 0.016666855663061142
# look back 56 - 0.01744994893670082 | best 54 - 0.016666855663061142
# look back 57 - 0.018329225480556488 | best 54 - 0.016666855663061142
# look back 58 - 0.018640335649251938 | best 54 - 0.016666855663061142
# look back 59 - 0.019427794963121414 | best 54 - 0.016666855663061142
# look back 60 - 0.021187881007790565 | best 54 - 0.016666855663061142

# %%
train
# Out:
# array([[0.00083703],
#        [0.04077997],
#        [0.09799917],
#        [0.18481566],
#        [0.15602191],
#        [0.02415661],
#        [0.13034192],
#        [0.3504801 ],
#        [0.16281858],
#        [0.02333632],
#        [0.12108104],
#        [0.09082752],
#        [0.07717393],
#        [0.4028613 ],
#        [0.22570947],
#        [0.1197351 ],
#        [0.07704   ],
#        [0.03277799],
#        [0.10405925],
#        [0.04653873],
#        [0.05798759],
#        [0.05423938],
#        [0.13672006],
#        [0.08265813],
#        [0.07145167],
#        [0.09391448],
#        [0.203699  ],
#        [0.2961403 ],
#        [0.5899805 ],
#        [0.6103343 ],
#        [0.17924105],
#        [0.0426884 ],
#        [0.08705086],
#        [0.06579036],
#        [0.01925163],
#        [0.03867067],
#        [0.04101434],
#        [0.0371975 ],
#        [0.00552438],
#        [0.0276219 ],
#        [0.00786806],
#        [0.04754316],
#        [0.00251108],
#        [0.07097992],
#        [0.00485476],
#        [0.01573611],
#        [0.08152647],
#        [0.00455343],
#        [0.03431812],
#        [0.03197445],
#        [0.04051213],
#        [0.00133924],
#        [0.04034472],
#        [0.02812412],
#        [0.06595776],
#        [0.02184642],
#        [0.01153424],
#        [0.06538858],
#        [0.04024428],
#        [0.11062154],
#        [0.28227913],
#        [0.        ],
#        [0.30310437],
#        [0.07533247],
#        [0.19991563],
#        [0.05875598],
#        [0.19067484],
#        [0.04797171],
#        [0.04081346],
#        [0.09698804],
#        [0.10099573],
#        [0.14396872],
#        [0.19532871],
#        [0.05688438],
#        [0.0154013 ],
#        [0.16755615],
#        [0.08114143],
#        [0.08018722],
#        [0.14976095],
#        [0.20055176],
#        [0.01573611],
#        [0.12511885],
#        [0.06599125],
#        [0.02832501],
#        [0.048715  ],
#        [0.0499538 ],
#        [0.0442888 ],
#        [0.05293361],
#        [0.08135907],
#        [0.06445111],
#        [0.05892673],
#        [0.09307745],
#        [0.0212605 ],
#        [0.06096908],
#        [0.22763798],
#        [0.04620392],
#        [0.10362399],
#        [0.07917944],
#        [0.02186316],
#        [0.05373716],
#        [0.02932944],
#        [0.0306352 ],
#        [0.0182472 ],
#        [0.452564  ],
#        [0.25706753],
#        [0.12592575],
#        [0.16656846],
#        [0.14534144],
#        [0.08337195],
#        [0.03445171],
#        [0.1532095 ],
#        [0.06143781],
#        [0.17256157],
#        [0.10713951],
#        [0.20825243],
#        [0.22911115],
#        [0.08698389],
#        [0.05698483],
#        [0.12896919],
#        [0.07673867],
#        [0.07077904],
#        [0.16580173],
#        [0.16486092],
#        [0.15277424],
#        [0.18883339],
#        [0.14584365],
#        [0.21786484],
#        [0.01764454],
#        [0.14637935],
#        [0.1500288 ],
#        [0.05748708],
#        [0.09347922],
#        [0.15650739],
#        [0.22231448],
#        [0.1757088 ],
#        [0.3473329 ],
#        [0.15920764],
#        [0.14573987],
#        [0.15009576],
#        [0.09257523],
#        [0.10916846],
#        [0.12866786],
#        [0.2687695 ],
#        [0.10831135],
#        [0.19177972],
#        [0.06143781],
#        [0.24190092],
#        [0.364877  ],
#        [0.11148871],
#        [0.28576115],
#        [0.33109456],
#        [0.26096842],
#        [0.35863277],
#        [0.33849388],
#        [0.25094083],
#        [0.3271438 ],
#        [0.25457352],
#        [0.10027588],
#        [0.26192263],
#        [0.22817367],
#        [0.12177108],
#        [0.02849241],
#        [0.13981706],
#        [0.04874848],
#        [0.09006415],
#        [0.06997214],
#        [0.05805622],
#        [0.24719094],
#        [0.26647606],
#        [0.15715022],
#        [0.24769315],
#        [0.1983755 ],
#        [0.25532684],
#        [0.20239323],
#        [0.16707067],
#        [0.40461907],
#        [0.05979724],
#        [0.39434037],
#        [0.16211547],
#        [0.09756391],
#        [0.01757791],
#        [0.13174811],
#        [0.16837643],
#        [0.2199708 ]], dtype=float32)

# %%
# quantidade de atrasos
look_back = 54

X_train, y_train = create_dataset(train, look_back)
X_test, y_test = create_dataset(test, look_back)

# %%
# reshape da entrada para ser [amostras, time steps, caracteristicas]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
X_train.shape
# Out:
# (129, 54, 1)

# %%
y_train.shape
# Out:
# (129,)

# %% [markdown]
# # Modelo LSTM

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(look_back, 1), dropout=0.2))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               66560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath='./modelo_lstm_ex4.hdf5', verbose=1, save_best_only=True, monitor='val_loss')

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=1, callbacks=[checkpointer])
# Out:
# Epoch 1/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0093
# Epoch 00001: val_loss improved from inf to 0.01745, saving model to .\modelo_lstm_ex4.hdf5
# 129/129 [==============================] - 1s 9ms/step - loss: 0.0104 - val_loss: 0.0174
# Epoch 2/100
# 124/129 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 00002: val_loss improved from 0.01745 to 0.01741, saving model to .\modelo_lstm_ex4.hdf5
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.0174
# Epoch 3/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0090
# Epoch 00003: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0260
# Epoch 4/100
# 117/129 [==========================>...] - ETA: 0s - loss: 0.0089
# Epoch 00004: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0237
# Epoch 5/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0096
# Epoch 00005: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0092 - val_loss: 0.0220
# Epoch 6/100
# 116/129 [=========================>....] - ETA: 0s - loss: 0.0087
# Epoch 00006: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0256
# Epoch 7/100
# 129/129 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 00007: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0090 - val_loss: 0.0211
# Epoch 8/100
# 123/129 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 00008: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0088 - val_loss: 0.0215
# Epoch 9/100
# 128/129 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 00009: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0091 - val_loss: 0.0207
# Epoch 10/100
# 116/129 [=========================>....] - ETA: 0s - loss: 0.0083
# Epoch 00010: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0084 - val_loss: 0.0197
# Epoch 11/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0085
# Epoch 00011: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0086 - val_loss: 0.0204
# Epoch 12/100
# 122/129 [===========================>..] - ETA: 0s - loss: 0.0085
# Epoch 00012: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0201
# Epoch 13/100
# 124/129 [===========================>..] - ETA: 0s - loss: 0.0090
# Epoch 00013: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0230
# Epoch 14/100
# 126/129 [============================>.] - ETA: 0s - loss: 0.0086
# Epoch 00014: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0202
# Epoch 15/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0089
# Epoch 00015: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0087 - val_loss: 0.0206
# Epoch 16/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0073
# Epoch 00016: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0084 - val_loss: 0.0236
# Epoch 17/100
# 125/129 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 00017: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0274
# Epoch 18/100
# 124/129 [===========================>..] - ETA: 0s - loss: 0.0093
# Epoch 00018: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0092 - val_loss: 0.0241
# Epoch 19/100
# 115/129 [=========================>....] - ETA: 0s - loss: 0.0089
# Epoch 00019: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0090 - val_loss: 0.0214
# Epoch 20/100
# 115/129 [=========================>....] - ETA: 0s - loss: 0.0064
# Epoch 00020: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0196
# Epoch 21/100
# 123/129 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 00021: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0086 - val_loss: 0.0230
# Epoch 22/100
# 116/129 [=========================>....] - ETA: 0s - loss: 0.0084
# Epoch 00022: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0212
# Epoch 23/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0094
# Epoch 00023: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0091 - val_loss: 0.0243
# Epoch 24/100
# 115/129 [=========================>....] - ETA: 0s - loss: 0.0083
# Epoch 00024: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0089 - val_loss: 0.0231
# Epoch 25/100
# 125/129 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 00025: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0219
# Epoch 26/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0089
# Epoch 00026: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0190
# Epoch 27/100
# 114/129 [=========================>....] - ETA: 0s - loss: 0.0081
# Epoch 00027: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0238
# Epoch 28/100
# 129/129 [==============================] - ETA: 0s - loss: 0.0090
# Epoch 00028: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0090 - val_loss: 0.0182
# Epoch 29/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0082
# Epoch 00029: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0088 - val_loss: 0.0200
# Epoch 30/100
# 116/129 [=========================>....] - ETA: 0s - loss: 0.0085
# Epoch 00030: val_loss did not improve from 0.01741
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0084 - val_loss: 0.0192
# Epoch 31/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0084
# Epoch 00031: val_loss did not improve from 0.01741
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0092 - val_loss: 0.0212
# Epoch 32/100
# 125/129 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 00032: val_loss improved from 0.01741 to 0.01725, saving model to .\modelo_lstm_ex4.hdf5
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0081 - val_loss: 0.0173
# Epoch 33/100
# 117/129 [==========================>...] - ETA: 0s - loss: 0.0078
# Epoch 00033: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0082 - val_loss: 0.0181
# Epoch 34/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0089
# Epoch 00034: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0216
# Epoch 35/100
# 128/129 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 00035: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 36/100
# 116/129 [=========================>....] - ETA: 0s - loss: 0.0092
# Epoch 00036: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0087 - val_loss: 0.0265
# Epoch 37/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0086
# Epoch 00037: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0211
# Epoch 38/100
# 125/129 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 00038: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0089 - val_loss: 0.0204
# Epoch 39/100
# 127/129 [============================>.] - ETA: 0s - loss: 0.0091
# Epoch 00039: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0090 - val_loss: 0.0182
# Epoch 40/100
# 122/129 [===========================>..] - ETA: 0s - loss: 0.0082
# Epoch 00040: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0204
# Epoch 41/100
# 120/129 [==========================>...] - ETA: 0s - loss: 0.0082
# Epoch 00041: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0234
# Epoch 42/100
# 122/129 [===========================>..] - ETA: 0s - loss: 0.0088
# Epoch 00042: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0087 - val_loss: 0.0202
# Epoch 43/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 00043: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0084 - val_loss: 0.0180
# Epoch 44/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0087
# Epoch 00044: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0185
# Epoch 45/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0087
# Epoch 00045: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0198
# Epoch 46/100
# 124/129 [===========================>..] - ETA: 0s - loss: 0.0091
# Epoch 00046: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0203
# Epoch 47/100
# 123/129 [===========================>..] - ETA: 0s - loss: 0.0086
# Epoch 00047: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0185
# Epoch 48/100
# 123/129 [===========================>..] - ETA: 0s - loss: 0.0080
# Epoch 00048: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0230
# Epoch 49/100
# 125/129 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 00049: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0094 - val_loss: 0.0205
# Epoch 50/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0086
# Epoch 00050: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0092 - val_loss: 0.0213
# Epoch 51/100
# 129/129 [==============================] - ETA: 0s - loss: 0.0082
# Epoch 00051: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0082 - val_loss: 0.0230
# Epoch 52/100
# 126/129 [============================>.] - ETA: 0s - loss: 0.0081
# Epoch 00052: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0232
# Epoch 53/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0084
# Epoch 00053: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0086 - val_loss: 0.0201
# Epoch 54/100
# 122/129 [===========================>..] - ETA: 0s - loss: 0.0085
# Epoch 00054: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0204
# Epoch 55/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0088
# Epoch 00055: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0216
# Epoch 56/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0095
# Epoch 00056: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0190
# Epoch 57/100
# 122/129 [===========================>..] - ETA: 0s - loss: 0.0084
# Epoch 00057: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0207
# Epoch 58/100
# 121/129 [===========================>..] - ETA: 0s - loss: 0.0083
# Epoch 00058: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0184
# Epoch 59/100
# 122/129 [===========================>..] - ETA: 0s - loss: 0.0077
# Epoch 00059: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0215
# Epoch 60/100
# 126/129 [============================>.] - ETA: 0s - loss: 0.0084
# Epoch 00060: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0083 - val_loss: 0.0213
# Epoch 61/100
# 123/129 [===========================>..] - ETA: 0s - loss: 0.0092
# Epoch 00061: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0202
# Epoch 62/100
# 126/129 [============================>.] - ETA: 0s - loss: 0.0087
# Epoch 00062: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0199
# Epoch 63/100
# 117/129 [==========================>...] - ETA: 0s - loss: 0.0081
# Epoch 00063: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0195
# Epoch 64/100
# 120/129 [==========================>...] - ETA: 0s - loss: 0.0081
# Epoch 00064: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0220
# Epoch 65/100
# 124/129 [===========================>..] - ETA: 0s - loss: 0.0085
# Epoch 00065: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0178
# Epoch 66/100
# 128/129 [============================>.] - ETA: 0s - loss: 0.0082
# Epoch 00066: val_loss did not improve from 0.01725
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0082 - val_loss: 0.0202
# Epoch 67/100
# 123/129 [===========================>..] - ETA: 0s - loss: 0.0076
# Epoch 00067: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0192
# Epoch 68/100
# 127/129 [============================>.] - ETA: 0s - loss: 0.0085
# Epoch 00068: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0174
# Epoch 69/100
# 125/129 [============================>.] - ETA: 0s - loss: 0.0077
# Epoch 00069: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0078 - val_loss: 0.0234
# Epoch 70/100
# 122/129 [===========================>..] - ETA: 0s - loss: 0.0093
# Epoch 00070: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0184
# Epoch 71/100
# 129/129 [==============================] - ETA: 0s - loss: 0.0081
# Epoch 00071: val_loss did not improve from 0.01725
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0190
# Epoch 72/100
# 124/129 [===========================>..] - ETA: 0s - loss: 0.0081
# Epoch 00072: val_loss improved from 0.01725 to 0.01696, saving model to .\modelo_lstm_ex4.hdf5
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0088 - val_loss: 0.0170
# Epoch 73/100
# 128/129 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 00073: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0229
# Epoch 74/100
# 114/129 [=========================>....] - ETA: 0s - loss: 0.0076
# Epoch 00074: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0184
# Epoch 75/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0079
# Epoch 00075: val_loss did not improve from 0.01696
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0083 - val_loss: 0.0178
# Epoch 76/100
# 115/129 [=========================>....] - ETA: 0s - loss: 0.0085
# Epoch 00076: val_loss did not improve from 0.01696
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0081 - val_loss: 0.0188
# Epoch 77/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0077
# Epoch 00077: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0205
# Epoch 78/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0073
# Epoch 00078: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0177
# Epoch 79/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0081
# Epoch 00079: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0283
# Epoch 80/100
# 117/129 [==========================>...] - ETA: 0s - loss: 0.0086
# Epoch 00080: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0198
# Epoch 81/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0088
# Epoch 00081: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0194
# Epoch 82/100
# 117/129 [==========================>...] - ETA: 0s - loss: 0.0079
# Epoch 00082: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0187
# Epoch 83/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0090
# Epoch 00083: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0188
# Epoch 84/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0087
# Epoch 00084: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0087 - val_loss: 0.0192
# Epoch 85/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0089
# Epoch 00085: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0085 - val_loss: 0.0186
# Epoch 86/100
# 129/129 [==============================] - ETA: 0s - loss: 0.0079
# Epoch 00086: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0186
# Epoch 87/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0080
# Epoch 00087: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0204
# Epoch 88/100
# 115/129 [=========================>....] - ETA: 0s - loss: 0.0081
# Epoch 00088: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0205
# Epoch 89/100
# 117/129 [==========================>...] - ETA: 0s - loss: 0.0086
# Epoch 00089: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0197
# Epoch 90/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0082
# Epoch 00090: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0081 - val_loss: 0.0196
# Epoch 91/100
# 115/129 [=========================>....] - ETA: 0s - loss: 0.0081
# Epoch 00091: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0079 - val_loss: 0.0185
# Epoch 92/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0080
# Epoch 00092: val_loss did not improve from 0.01696
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0190
# Epoch 93/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0088
# Epoch 00093: val_loss improved from 0.01696 to 0.01689, saving model to .\modelo_lstm_ex4.hdf5
# 129/129 [==============================] - 1s 5ms/step - loss: 0.0083 - val_loss: 0.0169
# Epoch 94/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0085
# Epoch 00094: val_loss did not improve from 0.01689
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0180
# Epoch 95/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0084
# Epoch 00095: val_loss did not improve from 0.01689
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0175
# Epoch 96/100
# 125/129 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 00096: val_loss did not improve from 0.01689
# 129/129 [==============================] - 1s 4ms/step - loss: 0.0076 - val_loss: 0.0198
# Epoch 97/100
# 123/129 [===========================>..] - ETA: 0s - loss: 0.0108
# Epoch 00097: val_loss did not improve from 0.01689
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0106 - val_loss: 0.0246
# Epoch 98/100
# 117/129 [==========================>...] - ETA: 0s - loss: 0.0080
# Epoch 00098: val_loss did not improve from 0.01689
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0184
# Epoch 99/100
# 118/129 [==========================>...] - ETA: 0s - loss: 0.0083
# Epoch 00099: val_loss did not improve from 0.01689
# 129/129 [==============================] - 0s 4ms/step - loss: 0.0082 - val_loss: 0.0204
# Epoch 100/100
# 119/129 [==========================>...] - ETA: 0s - loss: 0.0085
# Epoch 00100: val_loss did not improve from 0.01689
# 129/129 [==============================] - 0s 3ms/step - loss: 0.0082 - val_loss: 0.0187

# %%
plot_history(history)

# %%
model = load_model("./modelo_lstm_ex4.hdf5")

# %%
# Predições
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# %%
trainPredict.shape
# Out:
# (129, 1)

# %%
y_train.shape
# Out:
# (129,)

# %%
# Faz a transformação inversa das predições
trainPredict = scaler.inverse_transform(trainPredict)
y_tr = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_te = scaler.inverse_transform([y_test])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(y_tr[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_te[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 2576096.47 RMSE
# Test Score: 3881787.30 RMSE

# %%
# Prepara o vetor para plotagem do conjunto de treinamento
trainPredictPlot = np.empty_like(X)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back-1:len(trainPredict)+look_back-1, :] = trainPredict

# %%
# Prepara o vetor para plotagem do conjunto das predições
testPredictPlot = np.empty_like(X)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(X)-2, :] = testPredict

# %%
# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,14))
plt.plot(scaler.inverse_transform(X), color='b')
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
y_te = y_te.reshape(-1,1)

# %%
mean_absolute_percentage_error(testPredict, y_te)

# %% [markdown]
# # Modelo GRU

# %%
model = Sequential()
model.add(GRU(128, input_shape=(look_back, 1), dropout=0.2))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')

# %%
model.summary()

# %%
checkpointer = ModelCheckpoint(filepath='./modelo_gru_ex4.hdf5', verbose=1, save_best_only=True, monitor='val_loss')

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=1, callbacks=[checkpointer])

# %%
plot_history(history)

# %%
model = load_model("./modelo_gru_ex4.hdf5")

# %%
# Predições
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)

# %%
trainPredict.shape

# %%
y_train.shape

# %%
# Faz a transformação inversa das predições
trainPredict = scaler.inverse_transform(trainPredict)
y_tr = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_te = scaler.inverse_transform([y_test])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(y_tr[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_te[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# %%
# Prepara o vetor para plotagem do conjunto de treinamento
trainPredictPlot = np.empty_like(X)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back-1:len(trainPredict)+look_back-1, :] = trainPredict

# %%
# Prepara o vetor para plotagem do conjunto das predições
testPredictPlot = np.empty_like(X)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2):len(X)-2, :] = testPredict

# %%
# Plota o dataset, as predições sobre o conjunto de treinamento e teste
plt.figure(figsize=(20,14))
plt.plot(scaler.inverse_transform(X), color='b')
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
